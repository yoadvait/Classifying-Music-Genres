# %% [markdown]
# # Creating a Dataset

# %%
import numpy as np
import pandas as pd
import os

# %%
import IPython.display as ipd
import matplotlib.pyplot as plt

# %%
file1 = "Data/genres_original/pop/pop.00003.wav"

# %%
import librosa
import librosa.display

# %%
plt.figure(figsize=(16,9))
data1, sr1=librosa.load(file1)
librosa.display.waveshow(data1,sr=sr1)
ipd.Audio(file1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import pandas as pd

data=pd.read_csv('Data/features_3_sec.csv')
data.head(10)
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1  blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2  blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3  blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4  blues.00000.4.wav   66149          0.335579         0.088129  0.143289
# 5  blues.00000.5.wav   66149          0.376670         0.089702  0.132618
# 6  blues.00000.6.wav   66149          0.379909         0.088827  0.130335
# 7  blues.00000.7.wav   66149          0.331880         0.092119  0.140600
# 8  blues.00000.8.wav   66149          0.347877         0.094209  0.133130
# 9  blues.00000.9.wav   66149          0.358061         0.082957  0.115312
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.003521             1773.065032          167541.630869
# ...

# %%
data=pd.read_csv('Data/features_30_sec.csv')
data.head(10)
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
# 5  blues.00005.wav  661794          0.302456         0.087532  0.103494
# 6  blues.00006.wav  661794          0.291328         0.093981  0.141874
# 7  blues.00007.wav  661794          0.307955         0.092903  0.131822
# 8  blues.00008.wav  661794          0.408879         0.086512  0.142416
# 9  blues.00009.wav  661794          0.273950         0.092316  0.081314
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850           1.297741e+05
# ...

# %% [markdown]
# # Data Augmentation

# %%
import soundfile as sf
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift, Gain

# %%
os.makedirs('augmented_data', exist_ok=True)

# %%
augment = Compose([
    AddGaussianNoise(min_amplitude=0.005, max_amplitude=0.025, p=0.7),
    TimeStretch(min_rate=0.9, max_rate=1.2, p=0.5),
    PitchShift(min_semitones=-3, max_semitones=3, p=0.6),
    Shift(min_shift=-0.4, max_shift=0.4, p=0.6),
    Gain(min_gain_in_db=-10, max_gain_in_db=10, p=0.75)
])

# %%
def apply_n_keep(file, save_dir='augmented_data', augmentations=5):
    
    augmented_files=[]
    
    try:
        y, sr = librosa.load(file, res_type='kaiser_fast')
        augmented_files = []

        for i in range(augmentations):
            augmented_samples = augment(samples=y, sample_rate=sr)
            augmented_file_path = os.path.join(save_dir, f"aug_{i}_{os.path.basename(file)}")
            sf.write(augmented_file_path, augmented_samples, sr)
            augmented_files.append(augmented_file_path)
            
            
    except Exception as e:
        print(f"Error processing {file}: {e}")
            
    return augmented_files

# %%
from tqdm import tqdm

# %%
augmented_file_paths = []

for index_num, row in tqdm(data.iterrows(), total=data.shape[0]):
    file_name = os.path.join(os.path.abspath("Data/genres_original"), row['label'], str(row['filename']))
    augmented_files = apply_n_keep(file_name)
    augmented_file_paths.extend([(aug_file, row['label']) for aug_file in augmented_files])
# Out:
#  55%|██████████████████████▏                 | 554/1000 [10:10<07:35,  1.02s/it]/var/folders/l0/1187xf1x5bz0ltr7dq12m2f40000gn/T/ipykernel_66815/885119493.py:6: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(file, res_type='kaiser_fast')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#  56%|██████████████████████▏                 | 555/1000 [10:10<05:33,  1.34it/s]
# Error processing /Users/advaitk/Desktop/Music Genre Classification/Data/genres_original/jazz/jazz.00054.wav:
# 100%|███████████████████████████████████████| 1000/1000 [17:58<00:00,  1.08s/it]

# %% [markdown]
# # EDA

# %%
def features_extractor(file):
    try:
        audio, sample_rate = librosa.load(file, res_type='kaiser_fast')
        mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccs_scaled_features = np.mean(mfccs_features.T, axis=0)
        return mfccs_scaled_features
    except Exception as e:
        print(f"Error loading {file}: {e}")
        return None

# %%
extracted_features = []
corrupt_files = []

# %%
for index_num, row in tqdm(data.iterrows(), total=data.shape[0]):
    file_name = os.path.join(os.path.abspath("Data/genres_original"), row['label'], str(row['filename']))
    features = features_extractor(file_name)
    if features is not None:
        extracted_features.append([features, row['label']])
    else:
        corrupt_files.append(index_num)
# Out:
#  55%|██████████████████████                  | 553/1000 [00:24<00:18, 24.43it/s]/var/folders/l0/1187xf1x5bz0ltr7dq12m2f40000gn/T/ipykernel_66815/1263226154.py:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sample_rate = librosa.load(file, res_type='kaiser_fast')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#  56%|██████████████████████▎                 | 559/1000 [00:24<00:17, 25.81it/s]
# Error loading /Users/advaitk/Desktop/Music Genre Classification/Data/genres_original/jazz/jazz.00054.wav:
# 100%|███████████████████████████████████████| 1000/1000 [00:43<00:00, 22.86it/s]

# %%
augmented_features = []
for aug_file, label in tqdm(augmented_file_paths):
    features = features_extractor(aug_file)
    if features is not None:
        augmented_features.append([features, label])
# Out:
# 100%|███████████████████████████████████████| 4995/4995 [04:48<00:00, 17.33it/s]

# %%
print(len(augmented_features))
# Out:
# 4995

# %%
print(len(extracted_features))
# Out:
# 999

# %%
def extract_mel_spectrogram(file_path):
    try:
        y, sr = librosa.load(file_path, sr=None)
        S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
        S_dB = librosa.power_to_db(S, ref=np.max)
        return S_dB, sr
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None, None

# %%
def plot_spectrogram(S_dB, sr, title="Mel Spectrogram"):
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S_dB, sr=sr, x_axis='time', y_axis='mel')
    plt.colorbar(format='%+2.0f dB')
    plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
aug_file, label = augmented_file_paths[1000]
S_dB, sr = extract_mel_spectrogram(aug_file)
plot_spectrogram(S_dB, sr)

# %%
data.drop(labels=corrupt_files, axis=0, inplace=True)

# %%
data.shape
# Out:
# (999, 60)

# %%
all_features = extracted_features + augmented_features

# %%
finaldata = pd.DataFrame(all_features, columns=['feature', 'label'])

# %%
features = np.array(finaldata['feature'].tolist())
labels = np.array(finaldata['label'].tolist())

# %%
finaldata
# Out:
#                                                 feature  label
# 0     [-113.59882, 121.57067, -19.162262, 42.363937,...  blues
# 1     [-207.52383, 123.98514, 8.947019, 35.86715, 2....  blues
# 2     [-90.757164, 140.44087, -29.084547, 31.686693,...  blues
# 3     [-199.57513, 150.0861, 5.663404, 26.855278, 1....  blues
# 4     [-160.35417, 126.20948, -35.581394, 22.139256,...  blues
# ...                                                 ...    ...
# 5989  [-262.45523, 96.94377, -9.481586, 40.653713, 3...   rock
# 5990  [-236.90845, 42.233788, 11.718397, 18.076393, ...   rock
# 5991  [-213.24901, 57.612686, 0.7662934, 29.678333, ...   rock
# 5992  [-277.80917, 56.15747, 8.73884, 22.146572, 12....   rock
# 5993  [-69.55753, 59.052967, -2.2573056, 35.36123, -...   rock
#
# [5994 rows x 2 columns]

# %%
labels.shape
# Out:
# (5994,)

# %% [markdown]
# # Building Models

# %%
import tensorflow as tf

from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

labels = to_categorical(LabelEncoder().fit_transform(labels))

# %%
from sklearn.model_selection import train_test_split

features_train, features_test, label_train, label_test = train_test_split(features, labels, test_size=0.2, random_state=0)

# %%
features_train.shape
# Out:
# (4795, 40)

# %%
features_test.shape
# Out:
# (1199, 40)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Dense(1024, activation='relu', input_shape=(40,)),
    Dropout(0.3),
    
    Dense(512, activation='relu'),
    Dropout(0.3),
    
    Dense(256, activation='relu'),
    Dropout(0.3),
    
    Dense(256, activation='relu'),
    Dropout(0.3),
    
    Dense(128, activation='relu'),
    Dropout(0.3),
    
    Dense(64, activation='relu'),
    Dropout(0.3),
    
    Dense(32, activation='relu'),
    Dropout(0.3),
    
    Dense(10, activation='softmax') 
])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1024)           │        41,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ...

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)

history = model.fit(features_train, label_train, epochs=5000, batch_size=32, validation_data=(features_test, label_test), callbacks=[early_stopping])
# Out:
# Epoch 1/5000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1048 - loss: 3.2512 - val_accuracy: 0.0959 - val_loss: 2.2821
# Epoch 2/5000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1285 - loss: 2.3001 - val_accuracy: 0.1827 - val_loss: 2.2500
# Epoch 3/5000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1487 - loss: 2.2537 - val_accuracy: 0.2410 - val_loss: 2.1542
# Epoch 4/5000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1933 - loss: 2.1739 - val_accuracy: 0.2686 - val_loss: 2.0564
# Epoch 5/5000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2316 - loss: 2.1155 - val_accuracy: 0.3003 - val_loss: 1.9632
# Epoch 6/5000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2596 - loss: 2.0354 - val_accuracy: 0.3294 - val_loss: 1.9622
# Epoch 7/5000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2547 - loss: 2.0126 - val_accuracy: 0.3336 - val_loss: 1.9481
# Epoch 8/5000
# ...

# %%
test_loss, test_acc = model.evaluate(features_test, label_test, verbose=2)
print(f'\nTest accuracy: {test_acc}')
# Out:
# 38/38 - 0s - 1ms/step - accuracy: 0.7957 - loss: 0.8280
#
# Test accuracy: 0.795663058757782

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## ANN 1 (Using data augmentation)

# %%
train_data, test_data = train_test_split(data, test_size=0.6, random_state=0)

# %%
extracted_test_features = []
corrupt_files= []

for index_num, row in test_data.iterrows():
    file_name = os.path.join(os.path.abspath("Data/genres_original"), row['label'], str(row['filename']))
    features = features_extractor(file_name)
    if features is not None:
        extracted_test_features.append([features, row['label']])
    else:
        corrupt_files.append(index_num)

# %%
test_features = np.array([item[0] for item in extracted_test_features])
test_labels = np.array([item[1] for item in extracted_test_features])

# %%
data.shape
# Out:
# (999, 60)

# %%
os.makedirs('augmented_data2', exist_ok=True)

# %%
augmented_file_paths2 = []

for index_num, row in tqdm(train_data.iterrows(), total=train_data.shape[0]):
    file_name = os.path.join(os.path.abspath("Data/genres_original"), row['label'], str(row['filename']))
    augmented_files = apply_n_keep(file_name, save_dir='augmented_data2')
    augmented_file_paths2.extend([(aug_file, row['label']) for aug_file in augmented_files])
# Out:
# 100%|█████████████████████████████████████████| 399/399 [06:52<00:00,  1.03s/it]

# %%
len(augmented_file_paths2)
# Out:
# 1995

# %%
augmented_features2 = []
for aug_file, label in tqdm(augmented_file_paths2):
    features = features_extractor(aug_file)
    if features is not None:
        augmented_features2.append([features, label])
# Out:
# 100%|███████████████████████████████████████| 1995/1995 [01:47<00:00, 18.54it/s]

# %%
len(augmented_features2)
# Out:
# 1995

# %%
realtrain_data = []

for index_num, row in train_data.iterrows():
    file_name = os.path.join(os.path.abspath("Data/genres_original"), row['label'], str(row['filename']))
    features = features_extractor(file_name)
    if features is not None:
        realtrain_data.append([features, row['label']])

# %%
len(realtrain_data)
# Out:
# 399

# %%
all_train = realtrain_data + augmented_features2

# %%
len(all_train)
# Out:
# 2394

# %%
alltrain = pd.DataFrame(all_train, columns=['feature', 'label'])

# %%
all_train_features = np.array(alltrain['feature'].tolist())
all_train_labels = np.array(alltrain['label'].tolist())

# %%
all_train_labels = to_categorical(LabelEncoder().fit_transform(all_train_labels))

# %%
test_labels = to_categorical(LabelEncoder().fit_transform(test_labels))

# %%
test_features1, val_features, test_labels1, val_labels = train_test_split(test_features, test_labels, test_size=0.5, random_state=42)

# %%
modelANN3 = Sequential([
    Dense(1024, activation='relu', input_shape=(40,)),
    BatchNormalization(),
    Dropout(0.35),
    
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.35),
    
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.35),
    
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.35),
    
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),
    
    Dense(10, activation='softmax')
])

# %%
modelANN3.summary()
# Out:
# Model: "sequential_95"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_605 (Dense)               │ (None, 1024)           │        41,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_360         │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_550 (Dropout)           │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_606 (Dense)               │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
modelANN3.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_accuracy', patience=150, restore_best_weights=True)

history = modelANN3.fit(all_train_features, all_train_labels, epochs=500, batch_size=32, validation_data=(val_features, val_labels), callbacks=[early_stopping])
# Out:
# Epoch 1/500
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.1079 - loss: 3.1385 - val_accuracy: 0.1700 - val_loss: 2.2652
# Epoch 2/500
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1224 - loss: 2.9268 - val_accuracy: 0.3067 - val_loss: 1.9788
# Epoch 3/500
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1532 - loss: 2.7415 - val_accuracy: 0.3333 - val_loss: 1.8525
# Epoch 4/500
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1919 - loss: 2.6193 - val_accuracy: 0.3867 - val_loss: 1.7703
# Epoch 5/500
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2001 - loss: 2.5542 - val_accuracy: 0.4033 - val_loss: 1.7020
# Epoch 6/500
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2373 - loss: 2.4394 - val_accuracy: 0.4033 - val_loss: 1.6713
# Epoch 7/500
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2257 - loss: 2.4015 - val_accuracy: 0.3933 - val_loss: 1.6423
# Epoch 8/500
# ...

# %%
test_loss, test_acc = modelANN3.evaluate(test_features1, test_labels1, verbose=2)
print(f'\nTest accuracy: {test_acc}')
# Out:
# 10/10 - 0s - 3ms/step - accuracy: 0.6267 - loss: 1.5344
#
# Test accuracy: 0.6266666650772095

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## ANN 2(Without Augmentation)

# %%
data.shape
# Out:
# (999, 60)

# %%
extracted_features3 = []

for index_num, row in data.iterrows():
    file_name = os.path.join(os.path.abspath("Data/genres_original"), row['label'], str(row['filename']))
    features = features_extractor(file_name)
    if features is not None:
        extracted_features3.append([features, row['label']])

# %%
len(extracted_features3)
# Out:
# 999

# %%
myData2 = pd.DataFrame(extracted_features3, columns=['feature', 'label'])

# %%
features2 = np.array(myData2['feature'].tolist())
labels2 = np.array(myData2['label'].tolist())

# %%
labels2 = to_categorical(LabelEncoder().fit_transform(labels2))

# %%
features_train2, features_test2, label_train2, label_test2 = train_test_split(features2, labels2, test_size=0.4, random_state=0)

# %%
features_val2, features_testing2, label_val2, label_testing2= train_test_split(features_test2, label_test2, test_size=0.5, random_state=0)

# %%
features_train2.shape
# Out:
# (599, 40)

# %%
features_testing2.shape
# Out:
# (200, 40)

# %%
from tensorflow.keras.regularizers import l2
l2_reg=0.00005

# %%
model2 = Sequential()

model2.add(Dense(2048, activation='relu', input_shape=(40,), kernel_regularizer=l2(l2_reg)))
model2.add(BatchNormalization())
model2.add(Dropout(0.4))

model2.add(Dense(1024, activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.4))

model2.add(Dense(512, activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.4))

model2.add(Dense(256, activation='relu', kernel_regularizer=l2(l2_reg)))
model2.add(BatchNormalization())
model2.add(Dropout(0.4))

model2.add(Dense(128, activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.4))

model2.add(Dense(64, activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.3))

model2.add(Dense(32, activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.3))

model2.add(Dense(10, activation='softmax'))

# %%
model2.summary()
# Out:
# Model: "sequential_108"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_704 (Dense)               │ (None, 2048)           │        83,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_450         │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_638 (Dropout)           │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_705 (Dense)               │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model2.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_accuracy', patience=100, restore_best_weights=True)

history = model2.fit(features_train2, label_train2, epochs=500, batch_size=32, validation_data=(features_val2, label_val2), callbacks=[early_stopping])
# Out:
# Epoch 1/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.1132 - loss: 3.1210 - val_accuracy: 0.1050 - val_loss: 8.1995
# Epoch 2/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1864 - loss: 2.6453 - val_accuracy: 0.1500 - val_loss: 6.5620
# Epoch 3/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2236 - loss: 2.4096 - val_accuracy: 0.2150 - val_loss: 4.7291
# Epoch 4/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2713 - loss: 2.2483 - val_accuracy: 0.2450 - val_loss: 3.7739
# Epoch 5/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2674 - loss: 2.2844 - val_accuracy: 0.2500 - val_loss: 3.7357
# Epoch 6/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3085 - loss: 2.1192 - val_accuracy: 0.2900 - val_loss: 3.5073
# Epoch 7/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2980 - loss: 1.9783 - val_accuracy: 0.2750 - val_loss: 3.4521
# Epoch 8/500
# ...

# %%
test_loss, test_acc = model2.evaluate(features_testing2, label_testing2, verbose=2)
print(f'\nTest accuracy: {test_acc}')
# Out:
# 7/7 - 0s - 4ms/step - accuracy: 0.6850 - loss: 1.6986
#
# Test accuracy: 66.50000023841858

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## ANN 3 (Without augmentation) (Added features)

# %%
def extract_features2(file_name):
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
        
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccs_scaled = np.mean(mfccs.T, axis=0)
        
        zero_crossings = librosa.feature.zero_crossing_rate(audio)
        zero_crossings_mean = np.mean(zero_crossings)
        
        spectral_centroid = librosa.feature.spectral_centroid(y=audio, sr=sample_rate)
        spectral_centroid_mean = np.mean(spectral_centroid)
        
        chroma = librosa.feature.chroma_stft(y=audio, sr=sample_rate, n_chroma=12)
        chroma_mean = np.mean(chroma.T, axis=0)
        
        spectral_rolloff = librosa.feature.spectral_rolloff(y=audio, sr=sample_rate)
        spectral_rolloff_mean = np.mean(spectral_rolloff)

        spectral_contrast = librosa.feature.spectral_contrast(y=audio, sr=sample_rate)
        spectral_contrast_mean = np.mean(spectral_contrast.T, axis=0)
        
        tonnetz = librosa.feature.tonnetz(y=librosa.effects.harmonic(audio), sr=sample_rate)
        tonnetz_mean = np.mean(tonnetz.T, axis=0)
        
        features = np.hstack([mfccs_scaled, zero_crossings_mean, spectral_centroid_mean, chroma_mean, spectral_rolloff_mean, spectral_contrast_mean, tonnetz_mean])
        
        return features
    
    except Exception as e:
        print(f"Error encountered while parsing file: {file_name}")
        return None

# %%
data.shape
# Out:
# (999, 60)

# %%
extracted_features3 = []

for index_num, row in data.iterrows():
    file_name = os.path.join(os.path.abspath("Data/genres_original"), row['label'], str(row['filename']))
    features = extract_features2(file_name)
    if features is not None:
        extracted_features3.append([features, row['label']])

# %%
len(extracted_features3)
# Out:
# 999

# %%
myData2 = pd.DataFrame(extracted_features3, columns=['feature', 'label'])

# %%
features2 = np.array(myData2['feature'].tolist())
labels2 = np.array(myData2['label'].tolist())

# %%
labels2 = to_categorical(LabelEncoder().fit_transform(labels2))

# %%
features_train2, features_test2, label_train2, label_test2 = train_test_split(features2, labels2, test_size=0.4, random_state=0)

# %%
features_val2, features_testing2, label_val2, label_testing2= train_test_split(features_test2, label_test2, test_size=0.5, random_state=0)

# %%
features_train2.shape
# Out:
# (599, 68)

# %%
features_testing2.shape
# Out:
# (200, 68)

# %%
model3 = Sequential()

model3.add(Dense(2048, activation='relu', input_shape=(68,), kernel_regularizer=l2(l2_reg)))
model3.add(BatchNormalization())
model3.add(Dropout(0.4))

model3.add(Dense(1024, activation='relu'))
model3.add(BatchNormalization())
model3.add(Dropout(0.4))

model3.add(Dense(512, activation='relu'))
model3.add(BatchNormalization())
model3.add(Dropout(0.4))

model3.add(Dense(256, activation='relu', kernel_regularizer=l2(l2_reg)))
model3.add(BatchNormalization())
model3.add(Dropout(0.4))

model3.add(Dense(128, activation='relu'))
model3.add(BatchNormalization())
model3.add(Dropout(0.4))

model3.add(Dense(64, activation='relu'))
model3.add(BatchNormalization())
model3.add(Dropout(0.3))

model3.add(Dense(32, activation='relu'))
model3.add(BatchNormalization())
model3.add(Dropout(0.3))

model3.add(Dense(10, activation='softmax'))

# %%
model3.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_accuracy', patience=150, restore_best_weights=True)

history = model3.fit(features_train2, label_train2, epochs=500, batch_size=32, validation_data=(features_val2, label_val2), callbacks=[early_stopping])
# Out:
# Epoch 1/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.1010 - loss: 3.0949 - val_accuracy: 0.1000 - val_loss: 15.6541
# Epoch 2/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.1641 - loss: 2.8030 - val_accuracy: 0.1900 - val_loss: 7.5605
# Epoch 3/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.1479 - loss: 2.6935 - val_accuracy: 0.1100 - val_loss: 10.4433
# Epoch 4/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2391 - loss: 2.3839 - val_accuracy: 0.1450 - val_loss: 8.7056
# Epoch 5/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.2021 - loss: 2.4840 - val_accuracy: 0.1750 - val_loss: 6.2007
# Epoch 6/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.2082 - loss: 2.4131 - val_accuracy: 0.1800 - val_loss: 4.0300
# Epoch 7/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.2310 - loss: 2.3910 - val_accuracy: 0.2050 - val_loss: 2.9454
# Epoch 8/500
# ...

# %%
test_loss, test_acc = model3.evaluate(features_testing2, label_testing2, verbose=2)
print(f'\nTest accuracy: {test_acc}')
# Out:
# 7/7 - 0s - 7ms/step - accuracy: 0.6850 - loss: 1.1919
#
# Test accuracy: 0.6850000023841858

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# # CNN

# %%
image_dir = 'Data/images_original'

# %%
from PIL import Image

# %%
img1 = 'Data/images_original/hiphop/hiphop00015.png'

# %%
image = Image.open(img1)

# %%
plt.imshow(image)
plt.show()

# %%
image.size
# Out:
# (432, 288)

# %%
original_image = image

resized_image = image.resize((128, 128))

fig, axes = plt.subplots(1, 2, figsize=(10, 5))

axes[0].imshow(original_image)
axes[0].set_title("Original Image")


axes[1].imshow(resized_image)
axes[1].set_title("Resized Image")


plt.show()

# %%
myPath = "Data/genres_original"

# %%
import math

def extract_mfcc(dataset_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5, sr=22050, tracklen=30):

    mfccs = []
    labels = []

    samples_per_segment = int((sr*tracklen) / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        if dirpath is not dataset_path:

            semantic_label = dirpath.split("/")[-1]
            
            for f in filenames:

                file_path = os.path.join(dirpath, f)
                
                try:
                    signal, sample_rate = librosa.load(file_path, sr=sr)

                    for d in range(num_segments):

                        start = samples_per_segment * d
                        finish = start + samples_per_segment

                        mfcc = librosa.feature.mfcc(y=signal[start:finish], sr=sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                        mfcc = mfcc.T

                        if len(mfcc) == num_mfcc_vectors_per_segment:
                            mfccs.append(mfcc)
                            labels.append(semantic_label)
                            
                except Exception as e:
                    pass

    mfccs = np.array(mfccs)
    labels = np.array(labels)

    return mfccs, labels

# %%
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)
labels = to_categorical(labels, num_classes=10)

# %%
X_train, X_test, y_train, y_test = train_test_split(mfccs, labels, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

# %%
X_train = X_train[..., np.newaxis]
X_val = X_val[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# %% [markdown]
# # LSTM model

# %%
from keras.layers import LSTM

# %%
modelLSTM = Sequential([
    LSTM(128, return_sequences=True, input_shape=(130, 13)),
    Dropout(0.2),
    BatchNormalization(),
    
    LSTM(64, return_sequences=False),
    Dropout(0.2),
    BatchNormalization(),
    
    Dense(128, activation='relu'),
    Dropout(0.2),
    
    Dense(64, activation='relu'),
    Dropout(0.2),
    
    Dense(10, activation='softmax')
])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
modelLSTM.summary()
# Out:
# Model: "sequential_158"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 130, 128)       │        72,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_886 (Dropout)           │ (None, 130, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_686         │ (None, 130, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
op = Adam(learning_rate=0.001)

modelLSTM.compile(optimizer=op, loss='categorical_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True)

history = modelLSTM.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 32s 160ms/step - accuracy: 0.2789 - loss: 2.0390 - val_accuracy: 0.4815 - val_loss: 1.5501
# Epoch 2/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - accuracy: 0.4532 - loss: 1.5457 - val_accuracy: 0.5280 - val_loss: 1.3087
# Epoch 3/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 30s 162ms/step - accuracy: 0.5102 - loss: 1.3964 - val_accuracy: 0.5115 - val_loss: 1.3198
# Epoch 4/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 29s 153ms/step - accuracy: 0.5145 - loss: 1.3598 - val_accuracy: 0.5546 - val_loss: 1.2298
# Epoch 5/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 27s 146ms/step - accuracy: 0.5684 - loss: 1.2287 - val_accuracy: 0.5836 - val_loss: 1.1731
# Epoch 6/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 29s 153ms/step - accuracy: 0.5864 - loss: 1.1956 - val_accuracy: 0.5516 - val_loss: 1.2308
# Epoch 7/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 29s 152ms/step - accuracy: 0.6263 - loss: 1.1086 - val_accuracy: 0.6191 - val_loss: 1.0969
# Epoch 8/200
# ...

# %%
test_loss, test_acc = modelLSTM.evaluate(X_test, y_test, verbose=2)
print(f'\nTest accuracy: {test_acc}')
# Out:
# 63/63 - 2s - 33ms/step - accuracy: 0.8308 - loss: 0.6654
#
# Test accuracy: 0.8308308124542236

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# # CNN-LSTM model

# %%
from tensorflow.keras.layers import TimeDistributed, Reshape

# %%
modelCNN_LSTM = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(130,13,1), padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    BatchNormalization(),
    Dropout(0.3),

    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    BatchNormalization(),
    Dropout(0.3),

    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    BatchNormalization(),
    Dropout(0.3),

    Flatten(),

    Reshape((17, 128)),

    LSTM(128, return_sequences=True),
    Dropout(0.3),

    LSTM(64, return_sequences=False),
    Dropout(0.3),

    Dense(128, activation='relu'),
    Dropout(0.3),

    Dense(64, activation='relu'),
    Dropout(0.3),

    Dense(10, activation='softmax')
])

# %%
modelCNN_LSTM.summary()
# Out:
# Model: "sequential_169"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_164 (Conv2D)             │ (None, 130, 13, 64)    │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_161               │ (None, 65, 7, 64)      │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_718         │ (None, 65, 7, 64)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_959 (Dropout)           │ (None, 65, 7, 64)      │             0 │
# ...

# %%
op = Adam(learning_rate=0.001)

modelCNN_LSTM.compile(optimizer=op, loss='categorical_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=True)

history2 = modelCNN_LSTM.fit(X_train, y_train, epochs=300, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 28s 96ms/step - accuracy: 0.2827 - loss: 2.0047 - val_accuracy: 0.4825 - val_loss: 1.4860
# Epoch 2/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - accuracy: 0.4549 - loss: 1.5291 - val_accuracy: 0.5415 - val_loss: 1.2789
# Epoch 3/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - accuracy: 0.5241 - loss: 1.3775 - val_accuracy: 0.5976 - val_loss: 1.1480
# Epoch 4/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 0.6020 - loss: 1.1761 - val_accuracy: 0.6346 - val_loss: 1.0385
# Epoch 5/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - accuracy: 0.6141 - loss: 1.1259 - val_accuracy: 0.6527 - val_loss: 1.0154
# Epoch 6/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.6564 - loss: 1.0203 - val_accuracy: 0.6276 - val_loss: 1.0934
# Epoch 7/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 18s 97ms/step - accuracy: 0.6876 - loss: 0.9518 - val_accuracy: 0.6802 - val_loss: 0.9600
# Epoch 8/300
# ...

# %%
history3 = modelCNN_LSTM.fit(X_train, y_train, epochs=300, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - accuracy: 0.9472 - loss: 0.1858 - val_accuracy: 0.8649 - val_loss: 0.4939
# Epoch 2/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 18s 97ms/step - accuracy: 0.9435 - loss: 0.1973 - val_accuracy: 0.8724 - val_loss: 0.5107
# Epoch 3/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 20s 104ms/step - accuracy: 0.9416 - loss: 0.2041 - val_accuracy: 0.8654 - val_loss: 0.5469
# Epoch 4/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.9531 - loss: 0.1696 - val_accuracy: 0.8744 - val_loss: 0.5616
# Epoch 5/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 16s 87ms/step - accuracy: 0.9277 - loss: 0.2561 - val_accuracy: 0.8829 - val_loss: 0.5530
# Epoch 6/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.9548 - loss: 0.1587 - val_accuracy: 0.8559 - val_loss: 0.6412
# Epoch 7/300
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 16s 86ms/step - accuracy: 0.9246 - loss: 0.2821 - val_accuracy: 0.8669 - val_loss: 0.5643
# Epoch 8/300
# ...

# %%
test_loss, test_acc = modelCNN_LSTM.evaluate(X_test, y_test, verbose=2)
print(f'\nTest accuracy: {test_acc}')
# Out:
# 63/63 - 2s - 25ms/step - accuracy: 0.8929 - loss: 0.5489
#
# Test accuracy: 0.8928928971290588

# %%
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(history3.history['accuracy'])
plt.plot(history3.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
test1 = "awagaman reel.wav"
audio1, sr1 = librosa.load(test1)
mfccs_features = librosa.feature.mfcc(y=audio1, sr = sr1, n_mfcc=40)
mfccs_features_scaled = np.mean(mfccs_features.T, axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 test1 = "awagaman reel.wav"
# ----> 2 audio1, sr1 = librosa.load(test1)
#       3 mfccs_features = librosa.feature.mfcc(y=audio1, sr = sr1, n_mfcc=40)
#       4 mfccs_features_scaled = np.mean(mfccs_features.T, axis=0)
#
# NameError: name 'librosa' is not defined

# %%
mfccs_features_scaled
# Out:
# array([-68.31906   ,  99.02438   ,  32.36618   ,  28.282778  ,
#         13.465893  ,  -7.439408  ,  -2.5705166 ,  -2.3421419 ,
#         -4.1858006 ,   7.1573544 ,  -7.4931016 ,  -2.998165  ,
#          4.427644  ,  -3.5243266 ,  -0.5847135 ,   7.529974  ,
#         -5.9264107 ,   9.592964  ,  -3.6395733 ,  -0.1800461 ,
#         -0.20221981,   5.0286646 ,  -7.8511443 ,   2.0598416 ,
#         -3.2015173 ,  -1.8876319 ,  -2.4833283 ,   1.877505  ,
#          2.329779  ,   3.5328493 ,   1.4136717 ,   1.3437364 ,
#         -1.4124702 ,   1.5395421 ,  -0.77708405,  -1.4127406 ,
#         -2.5045853 ,  -1.9746406 ,  -3.4659007 ,  -1.7358135 ],
#       dtype=float32)

# %%
mfccs_features_scaled = mfccs_features_scaled.reshape(1,-1)

# %%
predicted_label = model.predict(mfccs_features_scaled)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step

# %%
predicted_class = np.argmax(predicted_label, axis=1)
print(f'Predicted class: {predicted_class}')
# Out:
# Predicted class: [7]

# %%
X_test1.shape
# Out:
# (1998, 130, 13)

# %%
test1 = "becon.wav"
audio1, sr1 = librosa.load(test1)
mfccs_features = librosa.feature.mfcc(y=audio1, sr = sr1, n_mfcc=40)
mfccs_features_scaled = np.mean(mfccs_features.T, axis=0)

# %%
mfccs_features_scaled
# Out:
# array([-1.1405377e+02,  9.9582047e+01,  3.1847519e+01,  3.3095650e+01,
#         1.2622780e+01,  7.4992199e+00,  1.7848401e-01,  1.2537281e+01,
#         4.2712307e+00,  9.1395006e+00,  1.6152501e+00,  7.8136353e+00,
#         6.4918466e-02,  2.9699414e+00,  2.8176656e-01,  3.9608119e+00,
#         4.6285927e-01,  2.1829207e+00,  2.1248646e+00,  5.1876507e+00,
#         2.3588696e+00,  4.3136249e+00,  1.4904761e-01,  2.4657693e+00,
#        -4.4226936e-01,  2.6584141e+00, -3.8562325e-01, -4.2418357e-02,
#        -4.5492659e+00,  4.5689800e-01,  2.7508965e+00,  6.1812057e+00,
#        -1.2919617e+00, -6.7368059e+00, -7.0137324e+00, -3.2307506e+00,
#        -3.0529597e+00,  9.8583740e-01,  9.4065346e-02,  2.1749029e+00],
#       dtype=float32)

# %%
mfccs_features_scaled = mfccs_features_scaled.reshape(1,-1)

# %%
predicted_label = model.predict(mfccs_features_scaled)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
predicted_class = np.argmax(predicted_label, axis=1)
print(f'Predicted class: {predicted_class}')
# Out:
# Predicted class: [9]

# %%
test1 = "dard hook.wav"
audio1, sr1 = librosa.load(test1)
mfccs_features = librosa.feature.mfcc(y=audio1, sr = sr1, n_mfcc=40)
mfccs_features_scaled = np.mean(mfccs_features.T, axis=0)

mfccs_features_scaled

mfccs_features_scaled = mfccs_features_scaled.reshape(1,-1)

predicted_label = model.predict(mfccs_features_scaled)

predicted_class = np.argmax(predicted_label, axis=1)
print(f'Predicted class: {predicted_class}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted class: [8]
